# %% [markdown]
# # importing libraries

# %%
import numpy as numpy
import pandas as pd
import seaborn as sns
import math
from math import sqrt
import math as m
import matplotlib.pyplot as plt

# %% [markdown]
# # creating the function

# %%
def student_info(name,age):
    print(name,age)

# %% [markdown]
# # call the function

# %%
# student_info("Akash",34)
# student_info("Aliice",18)
sqrt(9)
# Out:
# 3.0

# %% [markdown]
# # numpy operation

# %%
import numpy as np

# %% [markdown]
# #creating the array

# %%
x=np.array([[1,2],[2,3],[3,4]])
print(x)
y=np.array([[[1,2],[2,3]],[[3,4],[4,5]]])
print(y)
# Out:
# [[1 2]
#  [2 3]
#  [3 4]]
# [[[1 2]
#   [2 3]]
#
#  [[3 4]
#   [4 5]]]

# %% [markdown]
# # pandas operation

# %% [markdown]
# #import pandas

# %%
import pandas as pd

# %% [markdown]
# #create pandas series from a list

# %%
s=pd.Series([10,20,30],
name="Mynumbers")
print(f"pandas series:\n{s}")
print(f"pandas series:{type(s)}")
# Out:
# pandas series:
# 0    10
# 1    20
# 2    30
# Name: Mynumbers, dtype: int64
# pandas series:<class 'pandas.core.series.Series'>

# %%
data={"Name":["Alice","Bob","Charlie"],
"Age":[25,30,35],
"City":["New York","Los Angeles","Chicago"]}
df=pd.DataFrame(data)
print(f"pandas DataFrame:\n{df}")
# Out:
# pandas DataFrame:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago

# %% [markdown]
# #data from local

# %%
df = pd.read_csv(r"D:\basic\Python\Stress_Dataset.csv")

# %%
df
# Out:
#      Gender  Age  Have you recently experienced stress in your life?  \
# 0         0   20                                                  3
# 1         0   20                                                  2
# 2         0   20                                                  5
# 3         1   20                                                  3
# 4         0   20                                                  3
# ..      ...  ...                                                ...
# 838       0   21                                                  3
# 839       1   19                                                  3
# 840       1   19                                                  4
# 841       0   20                                                  5
# 842       0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# ...

# %%
df.head()
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
# 3       1   20                                                  3
# 4       0   20                                                  3
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
# ...

# %%
df.describe()
# Out:
#            Gender         Age  \
# count  843.000000  843.000000
# mean     0.349941   20.071174
# std      0.477234    5.429502
# min      0.000000   14.000000
# 25%      0.000000   19.000000
# 50%      0.000000   19.000000
# 75%      1.000000   20.000000
# max      1.000000  100.000000
#
#        Have you recently experienced stress in your life?  \
# count                                         843.000000
# mean                                            2.997628
# std                                             1.134639
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        Have you noticed a rapid heartbeat or palpitations?  \
# count                                         843.000000
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Have you recently experienced stress in your life?',
#        'Have you noticed a rapid heartbeat or palpitations?',
#        'Have you been dealing with anxiety or tension recently?',
#        'Do you face any sleep problems or difficulties falling asleep?',
#        'Have you been dealing with anxiety or tension recently?.1',
#        'Have you been getting headaches more often than usual?',
#        'Do you get irritated easily?',
#        'Do you have trouble concentrating on your academic tasks?',
#        'Have you been feeling sadness or low mood?',
#        'Have you been experiencing any illness or health issues?',
#        'Do you often feel lonely or isolated?',
#        'Do you feel overwhelmed with your academic workload?',
#        'Are you in competition with your peers, and does it affect you?',
#        'Do you find that your relationship often causes you stress?',
# ...

# %%
df.head(8)
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
# 3       1   20                                                  3
# 4       0   20                                                  3
# 5       0   20                                                  3
# 6       0   20                                                  2
# 7       0   20                                                  5
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  3
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      Gender  Age  Have you recently experienced stress in your life?  \
# 0         0   20                                                  3
# 1         0   20                                                  2
# 2         0   20                                                  5
# 3         1   20                                                  3
# 4         0   20                                                  3
# ..      ...  ...                                                ...
# 838       0   21                                                  3
# 839       1   19                                                  3
# 840       1   19                                                  4
# 841       0   20                                                  5
# 842       0   19                                                  4
#
#      Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                    4
# ...

# %% [markdown]
# # matplot operation

# %% [markdown]
# #import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x=[0,2,4,6,8]
y=[0,4,16,36,64]
fig,ax=plt.subplots()

plt.plot(x,y,)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("X vs Y")
plt.show()

# %% [markdown]
# # combined examp

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr=np.array([10,20,30,40,50])
df=pd.DataFrame({"numbers":arr})
plt.bar(df.index,df["numbers"])
plt.show()

# %%
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']

data = [23, 17, 35, 29, 12, 41]

# Creating plot
fig = plt.figure(figsize=(10, 7))
plt.pie(data, labels=cars,autopct='%1.1f%%')

# show plot
plt.show()

# %% [markdown]
# # data cleaning

# %%
df=pd.read_csv( "D:\basic\Python\5_sept\Iris.csv")
