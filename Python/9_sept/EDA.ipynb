# %% [markdown]
# # Diagnostives ->(anamolies) analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# #Detecting outliers

# %%
data=pd.read_csv(r'D:\basic\Python\StressLevelDataset.csv')
data.head()
# Out:
#    anxiety_level  self_esteem  mental_health_history  depression  headache  \
# 0             14           20                      0          11         2
# 1             15            8                      1          15         5
# 2             12           18                      1          14         2
# 3             16           12                      1          15         4
# 4             16           28                      0           7         2
#
#    blood_pressure  sleep_quality  breathing_problem  noise_level  \
# 0               1              2                  4            2
# 1               3              1                  4            3
# 2               1              2                  2            2
# 3               3              1                  3            4
# 4               3              5                  1            3
#
#    living_conditions  ...  basic_needs  academic_performance  study_load  \
# ...

# %%
sns.boxplot(x=data['anxiety_level'])
# Out:
# <Axes: xlabel='anxiety_level'>

# %%
sns.boxplot(x=data['depression'])
# Out:
# <Axes: xlabel='depression'>

# %%
Q1=data.quantile(0.25)
Q3=data.quantile(0.75)  
IQR=Q3-Q1
print(IQR)
# Out:
# anxiety_level                   10.0
# self_esteem                     15.0
# mental_health_history            1.0
# depression                      13.0
# headache                         2.0
# blood_pressure                   2.0
# sleep_quality                    3.0
# breathing_problem                2.0
# noise_level                      1.0
# living_conditions                1.0
# safety                           2.0
# basic_needs                      2.0
# academic_performance             2.0
# study_load                       1.0
# teacher_student_relationship     2.0
# future_career_concerns           3.0
# social_support                   2.0
# peer_pressure                    2.0
# extracurricular_activities       2.0
# bullying                         3.0
# stress_level                     2.0
# dtype: float64

# %% [markdown]
# # plotting

# %% [markdown]
# #histogram

# %%
data = pd.read_csv(r'D:\basic\Python\9_sept\data.csv')
data.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
sns.boxplot(x=data['Year'])
# Out:
# <Axes: xlabel='Year'>

# %%
print(data.isnull().sum())
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
data=data.dropna()

# %%
print(data.isnull().sum())
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
duplicate_rows_data=data[data.duplicated()]
print("number of duplicate rows:",duplicate_rows_data.shape)
# Out:
# number of duplicate rows: (349, 16)

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (7735, 16)

# %%
data.Make.value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title("no of car by make")
plt.xlabel("no of cars") 
plt.ylabel(" make")
# Out:
# Text(0, 0.5, ' make')

# %%
data.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
data['tot']=data['Engine HP']+data['MSRP']
data.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
def get_price_category(MSRP):
    if MSRP<30000:
        return "budget"
    elif 30000<=MSRP<60000:
        return "medium"
    else:
        return "high-end"
data['price_category']=data['MSRP'].apply(get_price_category)
data.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %% [markdown]
# #merging and joining

# %%
agg_df=data.groupby('price_category').agg({'MSRP':'mean','Engine HP':'mean'})
agg_df.reset_index(inplace=True)
agg_df.head(5)
# Out:
#   price_category           MSRP   Engine HP
# 0         budget   19493.264199  185.100037
# 1       high-end  141913.232012  455.494860
# 2         medium   40675.267289  280.450604
